# %%
import os
from datetime import datetime
import requests
import time
import pandas as pd
import spacy
nlp = spacy.load('en_core_web_sm')
from collections import Counter

# %%
#read in pickle file as dataframe and drop unnecessary columns
spacy_analysis = pd.read_pickle("vader_picke_file.pkl").drop(columns=['web_url','snippet','date','_id','article','VADER snippet neg', 'VADER snippet neu', 'VADER snippet pos', 'VADER snippet compound'])

# %%
spacy_analysis
# Out:
#                                                abstract  \
# 0     It was a year full of big environmental news, ...
# 1     The first federal regulations on climate-alter...
# 2     About $11 billion in oil and natural gas trade...
# 3     Recent years have been humbling for oil bulls,...
# 4     Crude oil traded over $90 for a fifth consecut...
# ...                                                 ...
# 1515  Weakened demand for semiconductors is hurting ...
# 1516  Innovation, investment and inviting geology ha...
# 1517  On one side of a barricade in remote British C...
# 1518  The United States’ recognition of Venezuela’s ...
# 1519  By 2070, there is the potential for a very dif...
#
#                       pub_date
# 0     2010-12-31T23:00:27+0000
# 1     2010-12-31T01:47:00+0000
# 2     2010-12-30T20:21:30+0000
# 3     2010-12-30T02:34:46+0000
# 4     2010-12-29T14:06:12+0000
# ...                        ...
# 1515  2019-02-04T11:36:40+0000
# 1516  2019-02-03T23:17:02+0000
# 1517  2019-01-27T23:45:27+0000
# 1518  2019-01-25T00:29:52+0000
# 1519  2019-01-10T16:58:07+0000
#
# [1262 rows x 2 columns]

# %%
master_df = pd.DataFrame(spacy_analysis)
master_df
# Out:
#                                                abstract  \
# 0     It was a year full of big environmental news, ...
# 1     The first federal regulations on climate-alter...
# 2     About $11 billion in oil and natural gas trade...
# 3     Recent years have been humbling for oil bulls,...
# 4     Crude oil traded over $90 for a fifth consecut...
# ...                                                 ...
# 1515  Weakened demand for semiconductors is hurting ...
# 1516  Innovation, investment and inviting geology ha...
# 1517  On one side of a barricade in remote British C...
# 1518  The United States’ recognition of Venezuela’s ...
# 1519  By 2070, there is the potential for a very dif...
#
#                       pub_date
# 0     2010-12-31T23:00:27+0000
# 1     2010-12-31T01:47:00+0000
# 2     2010-12-30T20:21:30+0000
# 3     2010-12-30T02:34:46+0000
# 4     2010-12-29T14:06:12+0000
# ...                        ...
# 1515  2019-02-04T11:36:40+0000
# 1516  2019-02-03T23:17:02+0000
# 1517  2019-01-27T23:45:27+0000
# 1518  2019-01-25T00:29:52+0000
# 1519  2019-01-10T16:58:07+0000
#
# [1262 rows x 2 columns]

# %%
master_df['pub_date'] = pd.to_datetime(master_df['pub_date'])

# %%
datetime.now()
# Out:
# datetime.datetime(2020, 2, 11, 16, 56, 58, 269566)

# %%
master_df['pub_date'] = master_df['pub_date'].dt.strftime('%Y-%m-%d')
master_df
# Out:
#                                                abstract    pub_date
# 0     It was a year full of big environmental news, ...  2010-12-31
# 1     The first federal regulations on climate-alter...  2010-12-31
# 2     About $11 billion in oil and natural gas trade...  2010-12-30
# 3     Recent years have been humbling for oil bulls,...  2010-12-30
# 4     Crude oil traded over $90 for a fifth consecut...  2010-12-29
# ...                                                 ...         ...
# 1515  Weakened demand for semiconductors is hurting ...  2019-02-04
# 1516  Innovation, investment and inviting geology ha...  2019-02-03
# 1517  On one side of a barricade in remote British C...  2019-01-27
# 1518  The United States’ recognition of Venezuela’s ...  2019-01-25
# 1519  By 2070, there is the potential for a very dif...  2019-01-10
#
# [1262 rows x 2 columns]

# %%
all_news_per_day = []
#Iterating through unique dates
for day in master_df['pub_date'].unique():
    #Finding all records with the corresponding day
    corr_day = master_df.loc[master_df['pub_date']== day]
    # Combine the news for those days
    combined_news = " ".join(s for s in corr_day["abstract"])
    #appending combined news to all news per day with the current day
    all_news_per_day.append((combined_news,day))

# %%
combined_news_day = pd.DataFrame(all_news_per_day,columns=['combined_absract', 'Date'])

# %%
combined_news_day
# Out:
#                                       combined_absract        Date
# 0    It was a year full of big environmental news, ...  2010-12-31
# 1    About $11 billion in oil and natural gas trade...  2010-12-30
# 2    Crude oil traded over $90 for a fifth consecut...  2010-12-29
# 3    PetroChina is selling its stake in a gas pipel...  2010-12-28
# 4    Over the last three presidential administratio...  2010-12-24
# ..                                                 ...         ...
# 965  Weakened demand for semiconductors is hurting ...  2019-02-04
# 966  Innovation, investment and inviting geology ha...  2019-02-03
# 967  On one side of a barricade in remote British C...  2019-01-27
# 968  The United States’ recognition of Venezuela’s ...  2019-01-25
# 969  By 2070, there is the potential for a very dif...  2019-01-10
#
# [970 rows x 2 columns]

# %%
#TOkenization and Lematization
tokens = []
lemma = []
for doc in nlp.pipe(combined_news_day['combined_absract'].astype('unicode').values, batch_size=50,
                        n_threads=3):
    if doc.is_parsed:
        tokens.append([n.text for n in doc])
        lemma.append([n.lemma_ for n in doc
                        if not n.is_stop
                        and not n.is_punct])
    else:
        # We want to make sure that the lists of parsed results have the
        # same number of entries of the original Dataframe, so add some blanks in case the parse fails
        tokens.append(None)
        lemma.append(None)
combined_news_day['abstract_tokens'] = tokens
combined_news_day['abstract_lemma'] = lemma

# %%
combined_news_day
# Out:
#                                       combined_absract        Date  \
# 0    It was a year full of big environmental news, ...  2010-12-31
# 1    About $11 billion in oil and natural gas trade...  2010-12-30
# 2    Crude oil traded over $90 for a fifth consecut...  2010-12-29
# 3    PetroChina is selling its stake in a gas pipel...  2010-12-28
# 4    Over the last three presidential administratio...  2010-12-24
# ..                                                 ...         ...
# 965  Weakened demand for semiconductors is hurting ...  2019-02-04
# 966  Innovation, investment and inviting geology ha...  2019-02-03
# 967  On one side of a barricade in remote British C...  2019-01-27
# 968  The United States’ recognition of Venezuela’s ...  2019-01-25
# 969  By 2070, there is the potential for a very dif...  2019-01-10
#
#                                        abstract_tokens  \
# 0    [It, was, a, year, full, of, big, environmenta...
# 1    [About, $, 11, billion, in, oil, and, natural,...
# 2    [Crude, oil, traded, over, $, 90, for, a, fift...
# 3    [PetroChina, is, selling, its, stake, in, a, g...
# 4    [Over, the, last, three, presidential, adminis...
# ..                                                 ...
# 965  [Weakened, demand, for, semiconductors, is, hu...
# 966  [Innovation, ,, investment, and, inviting, geo...
# 967  [On, one, side, of, a, barricade, in, remote, ...
# 968  [The, United, States, ’, recognition, of, Vene...
# 969  [By, 2070, ,, there, is, the, potential, for, ...
#
#                                         abstract_lemma
# 0    [year, big, environmental, news, BP, oil, spil...
# 1    [$, 11, billion, oil, natural, gas, trade, imp...
# 2    [crude, oil, trade, $, 90, fifth, consecutive,...
# 3    [PetroChina, sell, stake, gas, pipeline, opera...
# 4    [presidential, administration, Office, Foreign...
# ..                                                 ...
# 965  [weakened, demand, semiconductor, hurt, financ...
# 966  [Innovation, investment, invite, geology, give...
# 967  [barricade, remote, British, Columbia, member,...
# 968  [United, States, recognition, Venezuela, oppos...
# 969  [2070, potential, different, energy, system, e...
#
# [970 rows x 4 columns]

# %%
counts = []
for x in combined_news_day['abstract_lemma']:
    counts.append(Counter(x).most_common(10))

# %%
combined_news_day['counts'] = counts

# %%
combined_news_day['top_word'] = combined_news_day['counts'].apply(lambda x: x[0][0])

# %%
combined_news_day['top_word']
# Out:
# 0           climate
# 1               oil
# 2             crude
# 3            energy
# 4      presidential
#            ...
# 965        weakened
# 966             oil
# 967       barricade
# 968          United
# 969            2070
# Name: top_word, Length: 970, dtype: object

# %%
combined_news_day.loc[combined_news_day['top_word'] == 'gas']
# Out:
#                                       combined_absract        Date  \
# 32   Environmental concerns and other issues could ...  2010-10-13
# 54   A sewage treatment in England has produced a d...  2010-08-05
# 145  Alaskan natural gas could provide an alternati...  2011-12-10
# 148  The actor, who lives in upstate New York, is a...  2011-12-02
# 294  The Russian gas export monopoly said that it w...  2012-09-05
# 301  Gas and coal power won't disappear soon, but w...  2012-08-16
# 340  Are gas prices soaring, or collapsing? It depe...  2012-03-30
# 405  If ENI and its partners succeed in exporting l...  2013-10-03
# 465  As gas starts to flow from wells drilled into ...  2013-03-12
# 579  A Russian gas embargo might be just what the w...  2014-04-12
# 636  But oil and gas industry bankers expect Woodsi...  2015-09-14
# 640  The agency said the rules were designed to ens...  2015-08-18
# 692  As gas and oil prices fall, the Russian energy...  2015-02-11
#
#                                        abstract_tokens  \
# 32   [Environmental, concerns, and, other, issues, ...
# 54   [A, sewage, treatment, in, England, has, produ...
# 145  [Alaskan, natural, gas, could, provide, an, al...
# 148  [The, actor, ,, who, lives, in, upstate, New, ...
# 294  [The, Russian, gas, export, monopoly, said, th...
# 301  [Gas, and, coal, power, wo, n't, disappear, so...
# 340  [Are, gas, prices, soaring, ,, or, collapsing,...
# 405  [If, ENI, and, its, partners, succeed, in, exp...
# 465  [As, gas, starts, to, flow, from, wells, drill...
# 579  [A, Russian, gas, embargo, might, be, just, wh...
# 636  [But, oil, and, gas, industry, bankers, expect...
# 640  [The, agency, said, the, rules, were, designed...
# 692  [As, gas, and, oil, prices, fall, ,, the, Russ...
#
#                                         abstract_lemma  \
# 32   [environmental, concern, issue, complicate, ex...
# 54   [sewage, treatment, England, produce, demo, ca...
# 145  [alaskan, natural, gas, provide, alternative, ...
# 148  [actor, live, upstate, New, York, odd, neighbo...
# 294  [russian, gas, export, monopoly, say, strongly...
# 301  [gas, coal, power, will, disappear, soon, carb...
# 340  [gas, price, soar, collapse, depend, gas, talk...
# 405  [ENI, partner, succeed, export, liquefy, natur...
# 465  [gas, start, flow, well, drill, Utica, Shale, ...
# 579  [russian, gas, embargo, world, need, seriously...
# 636  [oil, gas, industry, banker, expect, Woodside,...
# 640  [agency, say, rule, design, ensure, oil, gas, ...
# 692  [gas, oil, price, fall, russian, energy, giant...
#
#                                                 counts top_word
# 32   [(gas, 2), (environmental, 1), (concern, 1), (...      gas
# 54   [(gas, 2), (Reliance, 2), (sewage, 1), (treatm...      gas
# 145  [(gas, 2), (oil, 2), (alaskan, 1), (natural, 1...      gas
# 148  [(gas, 2), (actor, 1), (live, 1), (upstate, 1)...      gas
# 294  [(gas, 2), (russian, 1), (export, 1), (monopol...      gas
# 301  [(gas, 1), (coal, 1), (power, 1), (will, 1), (...      gas
# 340  [(gas, 3), (price, 3), (soar, 1), (collapse, 1...      gas
# 405  [(gas, 2), (ENI, 1), (partner, 1), (succeed, 1...      gas
# 465  [(gas, 1), (start, 1), (flow, 1), (well, 1), (...      gas
# 579  [(gas, 2), (russian, 1), (embargo, 1), (world,...      gas
# 636  [(gas, 2), (oil, 1), (industry, 1), (banker, 1...      gas
# 640  [(gas, 2), (agency, 1), (say, 1), (rule, 1), (...      gas
# 692  [(gas, 1), (oil, 1), (price, 1), (fall, 1), (r...      gas

# %%
combined_news_day.loc[combined_news_day['top_word'] == 'Energy']
# Out:
#                                       combined_absract        Date  \
# 10   An Energy Department forecast projects that th...  2010-12-16
# 137  PetroBakken Energy said that it had paid $262 ...  2010-01-05
# 208  Energy Secretary Chu names a panel to study th...  2011-05-06
# 251  The Energy Department has offered a large loan...  2011-02-03
# 377  The French oil giant Total is acquiring a big ...  2012-01-03
# 588  The Energy Department detailed how much more i...  2014-03-12
#
#                                        abstract_tokens  \
# 10   [An, Energy, Department, forecast, projects, t...
# 137  [PetroBakken, Energy, said, that, it, had, pai...
# 208  [Energy, Secretary, Chu, names, a, panel, to, ...
# 251  [The, Energy, Department, has, offered, a, lar...
# 377  [The, French, oil, giant, Total, is, acquiring...
# 588  [The, Energy, Department, detailed, how, much,...
#
#                                         abstract_lemma  \
# 10   [Energy, Department, forecast, project, price,...
# 137  [PetroBakken, Energy, say, pay, $, 262, millio...
# 208  [Energy, Secretary, Chu, name, panel, study, c...
# 251  [Energy, Department, offer, large, loan, guara...
# 377  [french, oil, giant, Total, acquire, big, piec...
# 588  [Energy, Department, detail, expect, consumer,...
#
#                                                 counts top_word
# 10   [(Energy, 1), (Department, 1), (forecast, 1), ...   Energy
# 137  [(Energy, 2), (PetroBakken, 1), (say, 1), (pay...   Energy
# 208  [(Energy, 1), (Secretary, 1), (Chu, 1), (name,...   Energy
# 251  [(Energy, 1), (Department, 1), (offer, 1), (la...   Energy
# 377  [(Energy, 2), (shale, 2), (operation, 2), ($, ...   Energy
# 588  [(Energy, 1), (Department, 1), (detail, 1), (e...   Energy

# %%
combined_news_day.loc[combined_news_day['top_word'] == 'United']
# Out:
#                                       combined_absract        Date  \
# 266  The United States may soon wipe out its need f...  2012-12-13
# 279  After an attempt to take over Unocal was block...  2012-11-12
# 318  The United States is now a much more significa...  2012-06-09
# 527  The United States government took aim at Exxon...  2014-09-13
# 531  United States refinery production in recent we...  2014-08-28
# 574  The United States, Canada and Mexico — for dif...  2014-04-21
# 590  The United States’s new gas abundance offers a...  2014-03-07
# 669  A United States Geological Survey report ident...  2015-04-23
# 795  The United States was supposed to be a L.N.G. ...  2017-10-16
# 879  The United States, Saudi Arabia and Russia see...  2018-06-13
# 881  The United States has been exporting energy fo...  2018-06-06
# 968  The United States’ recognition of Venezuela’s ...  2019-01-25
#
#                                        abstract_tokens  \
# 266  [The, United, States, may, soon, wipe, out, it...
# 279  [After, an, attempt, to, take, over, Unocal, w...
# 318  [The, United, States, is, now, a, much, more, ...
# 527  [The, United, States, government, took, aim, a...
# 531  [United, States, refinery, production, in, rec...
# 574  [The, United, States, ,, Canada, and, Mexico, ...
# 590  [The, United, States, ’s, new, gas, abundance,...
# 669  [A, United, States, Geological, Survey, report...
# 795  [The, United, States, was, supposed, to, be, a...
# 879  [The, United, States, ,, Saudi, Arabia, and, R...
# 881  [The, United, States, has, been, exporting, en...
# 968  [The, United, States, ’, recognition, of, Vene...
#
#                                         abstract_lemma  \
# 266  [United, States, soon, wipe, need, import, oil...
# 279  [attempt, Unocal, block, United, States, say, ...
# 318  [United, States, significant, energy, producer...
# 527  [United, States, government, take, aim, Exxon,...
# 531  [United, States, refinery, production, recent,...
# 574  [United, States, Canada, Mexico, different, re...
# 590  [United, States, new, gas, abundance, offer, c...
# 669  [United, States, Geological, Survey, report, i...
# 795  [United, States, suppose, L.N.G., importer, pl...
# 879  [United, States, Saudi, Arabia, Russia, common...
# 881  [United, States, export, energy, decade, proje...
# 968  [United, States, recognition, Venezuela, oppos...
#
#                                                 counts top_word
# 266  [(United, 1), (States, 1), (soon, 1), (wipe, 1...   United
# 279  [(United, 3), (States, 3), (attempt, 2), (say,...   United
# 318  [(United, 1), (States, 1), (significant, 1), (...   United
# 527  [(United, 1), (States, 1), (government, 1), (t...   United
# 531  [(United, 2), (States, 2), (production, 2), (r...   United
# 574  [(United, 1), (States, 1), (Canada, 1), (Mexic...   United
# 590  [(United, 1), (States, 1), (new, 1), (gas, 1),...   United
# 669  [(United, 1), (States, 1), (Geological, 1), (S...   United
# 795  [(United, 1), (States, 1), (suppose, 1), (L.N....   United
# 879  [(United, 1), (States, 1), (Saudi, 1), (Arabia...   United
# 881  [(United, 1), (States, 1), (export, 1), (energ...   United
# 968  [(United, 1), (States, 1), (recognition, 1), (...   United

# %%
combined_news_day.loc[combined_news_day['top_word'] == 'China']
# Out:
#                                       combined_absract        Date  \
# 34   China’s deal with Chesapeake Energy involves a...  2010-10-11
# 487  China is turning the Xinjiang region into a na...  2014-12-20
# 521  Russian officials say that negotiations are he...  2014-09-25
# 561  China has an insatiable appetite for energy an...  2014-05-22
# 624  In China and other emerging markets, growth is...  2015-10-23
# 779  For years, China gobbled up metals, crops and ...  2016-01-09
# 789  China’s goal is to dominate Eurasia by relegat...  2017-11-03
#
#                                        abstract_tokens  \
# 34   [China, ’s, deal, with, Chesapeake, Energy, in...
# 487  [China, is, turning, the, Xinjiang, region, in...
# 521  [Russian, officials, say, that, negotiations, ...
# 561  [China, has, an, insatiable, appetite, for, en...
# 624  [In, China, and, other, emerging, markets, ,, ...
# 779  [For, years, ,, China, gobbled, up, metals, ,,...
# 789  [China, ’s, goal, is, to, dominate, Eurasia, b...
#
#                                         abstract_lemma  \
# 34   [China, deal, Chesapeake, Energy, involve, pot...
# 487  [China, turn, Xinjiang, region, national, hub,...
# 521  [russian, official, negotiation, heat, China, ...
# 561  [China, insatiable, appetite, energy, deal, na...
# 624  [China, emerge, market, growth, wane, demand, ...
# 779  [year, China, gobble, metal, crop, fuel, rapid...
# 789  [China, goal, dominate, Eurasia, relegate, Rus...
#
#                                                 counts top_word
# 34   [(China, 1), (deal, 1), (Chesapeake, 1), (Ener...    China
# 487  [(China, 1), (turn, 1), (Xinjiang, 1), (region...    China
# 521  [(China, 2), (russian, 1), (official, 1), (neg...    China
# 561  [(China, 1), (insatiable, 1), (appetite, 1), (...    China
# 624  [(China, 1), (emerge, 1), (market, 1), (growth...    China
# 779  [(China, 2), (year, 1), (gobble, 1), (metal, 1...    China
# 789  [(China, 1), (goal, 1), (dominate, 1), (Eurasi...    China

# %%
combined_news_day.loc[combined_news_day['top_word'] == 'Shell']
# Out:
#                                       combined_absract        Date  \
# 184  Shell was under pressure after it emerged that...  2011-08-16
# 324  Despite lively opposition, Shell will start te...  2012-05-23
# 689  Shell is dismantling its North Sea project, a ...  2015-02-18
#
#                                        abstract_tokens  \
# 184  [Shell, was, under, pressure, after, it, emerg...
# 324  [Despite, lively, opposition, ,, Shell, will, ...
# 689  [Shell, is, dismantling, its, North, Sea, proj...
#
#                                         abstract_lemma  \
# 184  [Shell, pressure, emerge, company, wait, day, ...
# 324  [despite, lively, opposition, Shell, start, te...
# 689  [Shell, dismantle, North, Sea, project, step, ...
#
#                                                 counts top_word
# 184  [(Shell, 1), (pressure, 1), (emerge, 1), (comp...    Shell
# 324  [(Shell, 2), (despite, 1), (lively, 1), (oppos...    Shell
# 689  [(Shell, 1), (dismantle, 1), (North, 1), (Sea,...    Shell

# %%
combined_news_day.loc[combined_news_day['top_word'] == 'Exxon']
# Out:
#                                       combined_absract        Date  \
# 179  Exxon Mobil struck an agreement to explore for...  2011-08-30
# 188  Exxon’s earnings were a bit lower than analyst...  2011-07-28
# 701  Exxon’s chief has extensive international busi...  2016-12-14
#
#                                        abstract_tokens  \
# 179  [Exxon, Mobil, struck, an, agreement, to, expl...
# 188  [Exxon, ’s, earnings, were, a, bit, lower, tha...
# 701  [Exxon, ’s, chief, has, extensive, internation...
#
#                                         abstract_lemma  \
# 179  [Exxon, Mobil, strike, agreement, explore, oil...
# 188  [Exxon, earning, bit, low, analyst, expect, de...
# 701  [Exxon, chief, extensive, international, busin...
#
#                                                 counts top_word
# 179  [(Exxon, 1), (Mobil, 1), (strike, 1), (agreeme...    Exxon
# 188  [(Exxon, 1), (earning, 1), (bit, 1), (low, 1),...    Exxon
# 701  [(Exxon, 1), (chief, 1), (extensive, 1), (inte...    Exxon

# %%
combined_news_day.loc[combined_news_day['top_word'] == 'President']
# Out:
#                                       combined_absract        Date  \
# 112  President Obama set out to attract bipartisan ...  2010-04-01
# 288  President Obama’s claim about pipeline constru...  2012-10-17
# 319  President Hu Jintao of China and President Ham...  2012-06-08
# 336  President Obama calls for the creation of an i...  2012-04-13
# 351  President Obama proposed new incentives for al...  2012-03-08
# 415  President Enrique Peña Nieto proposed opening ...  2013-08-12
# 454  President Obama will be doing Canada a favor i...  2013-03-31
# 567  President Obama has a legacy opportunity in Uk...  2014-05-07
# 718  At an energy conference in Istanbul, President...  2016-10-10
# 757  President Obama includes an overdue domestic p...  2016-03-10
# 826  President Trump aims to roll back the Obama ad...  2017-04-28
# 839  Even with President Trump’s blessing for the p...  2017-01-26
# 874  President Trump contradicted U.S. intelligence...  2018-07-16
#
#                                        abstract_tokens  \
# 112  [President, Obama, set, out, to, attract, bipa...
# 288  [President, Obama, ’s, claim, about, pipeline,...
# 319  [President, Hu, Jintao, of, China, and, Presid...
# 336  [President, Obama, calls, for, the, creation, ...
# 351  [President, Obama, proposed, new, incentives, ...
# 415  [President, Enrique, Peña, Nieto, proposed, op...
# 454  [President, Obama, will, be, doing, Canada, a,...
# 567  [President, Obama, has, a, legacy, opportunity...
# 718  [At, an, energy, conference, in, Istanbul, ,, ...
# 757  [President, Obama, includes, an, overdue, dome...
# 826  [President, Trump, aims, to, roll, back, the, ...
# 839  [Even, with, President, Trump, ’s, blessing, f...
# 874  [President, Trump, contradicted, U.S., intelli...
#
#                                         abstract_lemma  \
# 112  [President, Obama, set, attract, bipartisan, s...
# 288  [President, Obama, claim, pipeline, constructi...
# 319  [President, Hu, Jintao, China, President, Hami...
# 336  [President, Obama, call, creation, interagency...
# 351  [President, Obama, propose, new, incentive, al...
# 415  [President, Enrique, Peña, Nieto, propose, ope...
# 454  [President, Obama, Canada, favor, block, Keyst...
# 567  [President, Obama, legacy, opportunity, Ukrain...
# 718  [energy, conference, Istanbul, President, Vlad...
# 757  [President, Obama, include, overdue, domestic,...
# 826  [President, Trump, aim, roll, Obama, administr...
# 839  [President, Trump, blessing, project, block, p...
# 874  [President, Trump, contradict, U.S., intellige...
#
#                                                 counts   top_word
# 112  [(President, 1), (Obama, 1), (set, 1), (attrac...  President
# 288  [(President, 1), (Obama, 1), (claim, 1), (pipe...  President
# 319  [(President, 2), (China, 2), (Afghanistan, 2),...  President
# 336  [(President, 1), (Obama, 1), (call, 1), (creat...  President
# 351  [(President, 1), (Obama, 1), (propose, 1), (ne...  President
# 415  [(President, 1), (Enrique, 1), (Peña, 1), (Nie...  President
# 454  [(President, 1), (Obama, 1), (Canada, 1), (fav...  President
# 567  [(President, 1), (Obama, 1), (legacy, 1), (opp...  President
# 718  [(President, 2), (energy, 1), (conference, 1),...  President
# 757  [(President, 1), (Obama, 1), (include, 1), (ov...  President
# 826  [(President, 1), (Trump, 1), (aim, 1), (roll, ...  President
# 839  [(President, 1), (Trump, 1), (blessing, 1), (p...  President
# 874  [(President, 2), (Trump, 2), (Russia, 2), (con...  President
