# %%
import os
from datetime import datetime
import requests
import time
import pandas as pd
import spacy
nlp = spacy.load('en_core_web_sm')
from collections import Counter

# %%
#read in pickle file as dataframe and drop unnecessary columns
master_df = pd.read_pickle("vader_picke_file.pkl").drop(columns=['web_url', 'snippet', '_id', 'article', 'date', 'VADER snippet neg', 'VADER snippet neu', 'VADER snippet pos', 'VADER snippet compound'])
master_df
# Out:
#                                                abstract  \
# 0     It was a year full of big environmental news, ...
# 1     The first federal regulations on climate-alter...
# 2     About $11 billion in oil and natural gas trade...
# 3     Recent years have been humbling for oil bulls,...
# 4     Crude oil traded over $90 for a fifth consecut...
# ...                                                 ...
# 1515  Weakened demand for semiconductors is hurting ...
# 1516  Innovation, investment and inviting geology ha...
# 1517  On one side of a barricade in remote British C...
# 1518  The United States’ recognition of Venezuela’s ...
# 1519  By 2070, there is the potential for a very dif...
#
#                       pub_date
# 0     2010-12-31T23:00:27+0000
# 1     2010-12-31T01:47:00+0000
# 2     2010-12-30T20:21:30+0000
# 3     2010-12-30T02:34:46+0000
# 4     2010-12-29T14:06:12+0000
# ...                        ...
# 1515  2019-02-04T11:36:40+0000
# 1516  2019-02-03T23:17:02+0000
# 1517  2019-01-27T23:45:27+0000
# 1518  2019-01-25T00:29:52+0000
# 1519  2019-01-10T16:58:07+0000
#
# [1262 rows x 2 columns]

# %%
master_df['pub_date'] = pd.to_datetime(master_df['pub_date'])

# %%
datetime.now()
# Out:
# datetime.datetime(2020, 2, 9, 21, 31, 28, 382925)

# %%
#Converting date to year month day format

master_df['pub_date'] = master_df['pub_date'].dt.strftime('%Y-%m-%d')

# %%
master_df.sort_values(by=['pub_date'], inplace=True, ascending=True)
master_df
# Out:
#                                                abstract    pub_date
# 229   The two countries failed to renew an agreement...  2010-01-04
# 227   PetroBakken Energy said that it had paid $262 ...  2010-01-05
# 226   The secretary, Ken Salazar, said the goal of t...  2010-01-06
# 225   If adopted, the standard will impose large cos...  2010-01-07
# 223   Spectra Energy has been quietly investigating ...  2010-01-13
# ...                                                 ...         ...
# 1446  It remains to be seen whether the reduction in...  2019-12-05
# 1445  The oil giant’s shares reached prices on the R...  2019-12-11
# 1444  Immense amounts of methane are escaping from o...  2019-12-12
# 1441  Twelve states and the District of Columbia rel...  2019-12-17
# 1440  The size and location of the parcel make it an...  2019-12-24
#
# [1262 rows x 2 columns]

# %%
all_news_per_day = []
#Iterating through unique dates
for day in master_df['pub_date'].unique():
    #Finding all records with the corresponding day
    corr_day = master_df.loc[master_df['pub_date']== day]
    # Combine the news for those days
    combined_news = " ".join(s for s in corr_day["abstract"])
    #appending combined news to all news per day with the current day
    all_news_per_day.append((combined_news,day))

# %%
combined_news_day = pd.DataFrame(all_news_per_day,columns=['combined_absract', 'Date'])
combined_news_day
# Out:
#                                       combined_absract        Date
# 0    The two countries failed to renew an agreement...  2010-01-04
# 1    PetroBakken Energy said that it had paid $262 ...  2010-01-05
# 2    The secretary, Ken Salazar, said the goal of t...  2010-01-06
# 3    If adopted, the standard will impose large cos...  2010-01-07
# 4    Spectra Energy has been quietly investigating ...  2010-01-13
# ..                                                 ...         ...
# 965  It remains to be seen whether the reduction in...  2019-12-05
# 966  The oil giant’s shares reached prices on the R...  2019-12-11
# 967  Immense amounts of methane are escaping from o...  2019-12-12
# 968  Twelve states and the District of Columbia rel...  2019-12-17
# 969  The size and location of the parcel make it an...  2019-12-24
#
# [970 rows x 2 columns]

# %%
# Tokenization and Lemmatization
tokens = []
lemma = []
for doc in nlp.pipe(combined_news_day['combined_absract'].astype('unicode').values, batch_size=50,
                        n_threads=3):
    if doc.is_parsed:
        tokens.append([n.text for n in doc])
        lemma.append([n.lemma_ for n in doc
                        if not n.is_stop
                        and not n.is_punct])
    else:
        # We want to make sure that the lists of parsed results have the
        # same number of entries of the original Dataframe, so add some blanks in case the parse fails
        tokens.append(None)
        lemma.append(None)
combined_news_day['abstract_tokens'] = tokens
combined_news_day['abstract_lemma'] = lemma

# %%
combined_news_day
# Out:
#                                       combined_absract        Date  \
# 0    The two countries failed to renew an agreement...  2010-01-04
# 1    PetroBakken Energy said that it had paid $262 ...  2010-01-05
# 2    The secretary, Ken Salazar, said the goal of t...  2010-01-06
# 3    If adopted, the standard will impose large cos...  2010-01-07
# 4    Spectra Energy has been quietly investigating ...  2010-01-13
# ..                                                 ...         ...
# 965  It remains to be seen whether the reduction in...  2019-12-05
# 966  The oil giant’s shares reached prices on the R...  2019-12-11
# 967  Immense amounts of methane are escaping from o...  2019-12-12
# 968  Twelve states and the District of Columbia rel...  2019-12-17
# 969  The size and location of the parcel make it an...  2019-12-24
#
#                                        abstract_tokens  \
# 0    [The, two, countries, failed, to, renew, an, a...
# 1    [PetroBakken, Energy, said, that, it, had, pai...
# 2    [The, secretary, ,, Ken, Salazar, ,, said, the...
# 3    [If, adopted, ,, the, standard, will, impose, ...
# 4    [Spectra, Energy, has, been, quietly, investig...
# ..                                                 ...
# 965  [It, remains, to, be, seen, whether, the, redu...
# 966  [The, oil, giant, ’s, shares, reached, prices,...
# 967  [Immense, amounts, of, methane, are, escaping,...
# 968  [Twelve, states, and, the, District, of, Colum...
# 969  [The, size, and, location, of, the, parcel, ma...
#
#                                         abstract_lemma
# 0    [country, fail, renew, agreement, crude, oil, ...
# 1    [PetroBakken, Energy, say, pay, $, 262, millio...
# 2    [secretary, Ken, Salazar, say, goal, new, revi...
# 3    [adopt, standard, impose, large, cost, local, ...
# 4    [Spectra, Energy, quietly, investigate, approa...
# ..                                                 ...
# 965  [remain, see, reduction, output, impact, price...
# 966  [oil, giant, share, reach, price, Riyadh, exch...
# 967  [immense, amount, methane, escape, oil, gas, s...
# 968  [state, District, Columbia, release, draft, pl...
# 969  [size, location, parcel, attractive, piece, re...
#
# [970 rows x 4 columns]

# %%
# Counting the words
counts = []
for x in combined_news_day['abstract_lemma']:
    counts.append(Counter(x).most_common(10))

# %%
combined_news_day['counts'] = counts

# %%
combined_news_day
# Out:
#                                       combined_absract        Date  \
# 0    The two countries failed to renew an agreement...  2010-01-04
# 1    PetroBakken Energy said that it had paid $262 ...  2010-01-05
# 2    The secretary, Ken Salazar, said the goal of t...  2010-01-06
# 3    If adopted, the standard will impose large cos...  2010-01-07
# 4    Spectra Energy has been quietly investigating ...  2010-01-13
# ..                                                 ...         ...
# 965  It remains to be seen whether the reduction in...  2019-12-05
# 966  The oil giant’s shares reached prices on the R...  2019-12-11
# 967  Immense amounts of methane are escaping from o...  2019-12-12
# 968  Twelve states and the District of Columbia rel...  2019-12-17
# 969  The size and location of the parcel make it an...  2019-12-24
#
#                                        abstract_tokens  \
# 0    [The, two, countries, failed, to, renew, an, a...
# 1    [PetroBakken, Energy, said, that, it, had, pai...
# 2    [The, secretary, ,, Ken, Salazar, ,, said, the...
# 3    [If, adopted, ,, the, standard, will, impose, ...
# 4    [Spectra, Energy, has, been, quietly, investig...
# ..                                                 ...
# 965  [It, remains, to, be, seen, whether, the, redu...
# 966  [The, oil, giant, ’s, shares, reached, prices,...
# 967  [Immense, amounts, of, methane, are, escaping,...
# 968  [Twelve, states, and, the, District, of, Colum...
# 969  [The, size, and, location, of, the, parcel, ma...
#
#                                         abstract_lemma  \
# 0    [country, fail, renew, agreement, crude, oil, ...
# 1    [PetroBakken, Energy, say, pay, $, 262, millio...
# 2    [secretary, Ken, Salazar, say, goal, new, revi...
# 3    [adopt, standard, impose, large, cost, local, ...
# 4    [Spectra, Energy, quietly, investigate, approa...
# ..                                                 ...
# 965  [remain, see, reduction, output, impact, price...
# 966  [oil, giant, share, reach, price, Riyadh, exch...
# 967  [immense, amount, methane, escape, oil, gas, s...
# 968  [state, District, Columbia, release, draft, pl...
# 969  [size, location, parcel, attractive, piece, re...
#
#                                                 counts
# 0    [(country, 1), (fail, 1), (renew, 1), (agreeme...
# 1    [(Energy, 2), (PetroBakken, 1), (say, 1), (pay...
# 2    [(secretary, 1), (Ken, 1), (Salazar, 1), (say,...
# 3    [(adopt, 1), (standard, 1), (impose, 1), (larg...
# 4    [(Spectra, 1), (Energy, 1), (quietly, 1), (inv...
# ..                                                 ...
# 965  [(remain, 1), (see, 1), (reduction, 1), (outpu...
# 966  [(oil, 1), (giant, 1), (share, 1), (reach, 1),...
# 967  [(immense, 1), (amount, 1), (methane, 1), (esc...
# 968  [(state, 1), (District, 1), (Columbia, 1), (re...
# 969  [(size, 1), (location, 1), (parcel, 1), (attra...
#
# [970 rows x 5 columns]

# %%
#adding Top world column to search on
combined_news_day['top_word'] = combined_news_day['counts'].apply(lambda x: x[0][0])

# %%
combined_news_day['top_word']
# Out:
# 0        country
# 1         Energy
# 2      secretary
# 3          adopt
# 4        Spectra
#          ...
# 965       remain
# 966          oil
# 967      immense
# 968        state
# 969         size
# Name: top_word, Length: 970, dtype: object

# %%
combined_news_day
# Out:
#                                       combined_absract        Date  \
# 0    The two countries failed to renew an agreement...  2010-01-04
# 1    PetroBakken Energy said that it had paid $262 ...  2010-01-05
# 2    The secretary, Ken Salazar, said the goal of t...  2010-01-06
# 3    If adopted, the standard will impose large cos...  2010-01-07
# 4    Spectra Energy has been quietly investigating ...  2010-01-13
# ..                                                 ...         ...
# 965  It remains to be seen whether the reduction in...  2019-12-05
# 966  The oil giant’s shares reached prices on the R...  2019-12-11
# 967  Immense amounts of methane are escaping from o...  2019-12-12
# 968  Twelve states and the District of Columbia rel...  2019-12-17
# 969  The size and location of the parcel make it an...  2019-12-24
#
#                                        abstract_tokens  \
# 0    [The, two, countries, failed, to, renew, an, a...
# 1    [PetroBakken, Energy, said, that, it, had, pai...
# 2    [The, secretary, ,, Ken, Salazar, ,, said, the...
# 3    [If, adopted, ,, the, standard, will, impose, ...
# 4    [Spectra, Energy, has, been, quietly, investig...
# ..                                                 ...
# 965  [It, remains, to, be, seen, whether, the, redu...
# 966  [The, oil, giant, ’s, shares, reached, prices,...
# 967  [Immense, amounts, of, methane, are, escaping,...
# 968  [Twelve, states, and, the, District, of, Colum...
# 969  [The, size, and, location, of, the, parcel, ma...
#
#                                         abstract_lemma  \
# 0    [country, fail, renew, agreement, crude, oil, ...
# 1    [PetroBakken, Energy, say, pay, $, 262, millio...
# 2    [secretary, Ken, Salazar, say, goal, new, revi...
# 3    [adopt, standard, impose, large, cost, local, ...
# 4    [Spectra, Energy, quietly, investigate, approa...
# ..                                                 ...
# 965  [remain, see, reduction, output, impact, price...
# 966  [oil, giant, share, reach, price, Riyadh, exch...
# 967  [immense, amount, methane, escape, oil, gas, s...
# 968  [state, District, Columbia, release, draft, pl...
# 969  [size, location, parcel, attractive, piece, re...
#
#                                                 counts   top_word
# 0    [(country, 1), (fail, 1), (renew, 1), (agreeme...    country
# 1    [(Energy, 2), (PetroBakken, 1), (say, 1), (pay...     Energy
# 2    [(secretary, 1), (Ken, 1), (Salazar, 1), (say,...  secretary
# 3    [(adopt, 1), (standard, 1), (impose, 1), (larg...      adopt
# 4    [(Spectra, 1), (Energy, 1), (quietly, 1), (inv...    Spectra
# ..                                                 ...        ...
# 965  [(remain, 1), (see, 1), (reduction, 1), (outpu...     remain
# 966  [(oil, 1), (giant, 1), (share, 1), (reach, 1),...        oil
# 967  [(immense, 1), (amount, 1), (methane, 1), (esc...    immense
# 968  [(state, 1), (District, 1), (Columbia, 1), (re...      state
# 969  [(size, 1), (location, 1), (parcel, 1), (attra...       size
#
# [970 rows x 6 columns]

# %%
#filtering out required top words
combined_news_day.loc[combined_news_day['top_word'] == 'gas']
# Out:
#                                       combined_absract        Date  \
# 106  Environmental concerns and other issues could ...  2010-10-13
# 178  Natural gas is cheaper than oil. It’s cleaner....  2011-04-12
# 250  Americans have signed millions of leases allow...  2011-12-02
# 280  The Thai oil and gas company PTT Exploration a...  2012-02-24
# 297  Are gas prices soaring, or collapsing? It depe...  2012-03-30
# 336  Gas and coal power won't disappear soon, but w...  2012-08-16
# 343  The oil and natural gas boom might distract us...  2012-09-05
# 351  Excelerate Energy is positioning itself to cap...  2012-10-23
# 354  Exxon Mobil and Royal Dutch Shell reported lac...  2012-11-01
# 379  Oil and gas made Norway one of the richest cou...  2013-01-28
# 455  If ENI and its partners succeed in exporting l...  2013-10-03
# 490  Islamist rebels and extremists are using oil a...  2014-01-29
# 511  While China is eager to wean itself from energ...  2014-04-12
# 616  As gas and oil prices fall, the Russian energy...  2015-02-11
# 668  The agency said the rules were designed to ens...  2015-08-18
# 672  But oil and gas industry bankers expect Woodsi...  2015-09-14
#
#                                        abstract_tokens  \
# 106  [Environmental, concerns, and, other, issues, ...
# 178  [Natural, gas, is, cheaper, than, oil, ., It, ...
# 250  [Americans, have, signed, millions, of, leases...
# 280  [The, Thai, oil, and, gas, company, PTT, Explo...
# 297  [Are, gas, prices, soaring, ,, or, collapsing,...
# 336  [Gas, and, coal, power, wo, n't, disappear, so...
# 343  [The, oil, and, natural, gas, boom, might, dis...
# 351  [Excelerate, Energy, is, positioning, itself, ...
# 354  [Exxon, Mobil, and, Royal, Dutch, Shell, repor...
# 379  [Oil, and, gas, made, Norway, one, of, the, ri...
# 455  [If, ENI, and, its, partners, succeed, in, exp...
# 490  [Islamist, rebels, and, extremists, are, using...
# 511  [While, China, is, eager, to, wean, itself, fr...
# 616  [As, gas, and, oil, prices, fall, ,, the, Russ...
# 668  [The, agency, said, the, rules, were, designed...
# 672  [But, oil, and, gas, industry, bankers, expect...
#
#                                         abstract_lemma  \
# 106  [environmental, concern, issue, complicate, ex...
# 178  [natural, gas, cheap, oil, clean, Congress, ac...
# 250  [Americans, sign, million, lease, allow, oil, ...
# 280  [Thai, oil, gas, company, PTT, Exploration, Pr...
# 297  [gas, price, soar, collapse, depend, gas, talk...
# 336  [gas, coal, power, will, disappear, soon, carb...
# 343  [oil, natural, gas, boom, distract, urgent, ch...
# 351  [Excelerate, Energy, position, capitalize, ame...
# 354  [Exxon, Mobil, Royal, Dutch, Shell, report, la...
# 379  [oil, gas, Norway, rich, country, siege, kill,...
# 455  [ENI, partner, succeed, export, liquefy, natur...
# 490  [islamist, rebel, extremist, oil, gas, proceed...
# 511  [China, eager, wean, energy, import, coal, ext...
# 616  [gas, oil, price, fall, russian, energy, giant...
# 668  [agency, say, rule, design, ensure, oil, gas, ...
# 672  [oil, gas, industry, banker, expect, Woodside,...
#
#                                                 counts top_word
# 106  [(gas, 2), (environmental, 1), (concern, 1), (...      gas
# 178  [(gas, 2), (oil, 2), (natural, 1), (cheap, 1),...      gas
# 250  [(gas, 2), (Americans, 1), (sign, 1), (million...      gas
# 280  [(gas, 2), ($, 2), (billion, 2), (exploration,...      gas
# 297  [(gas, 3), (price, 3), (soar, 1), (collapse, 1...      gas
# 336  [(gas, 1), (coal, 1), (power, 1), (will, 1), (...      gas
# 343  [(gas, 2), (oil, 1), (natural, 1), (boom, 1), ...      gas
# 351  [(gas, 2), (international, 2), (energy, 2), (E...      gas
# 354  [(gas, 2), (Island, 2), (Exxon, 1), (Mobil, 1)...      gas
# 379  [(gas, 2), (Hess, 2), (plan, 2), (oil, 1), (No...      gas
# 455  [(gas, 2), (ENI, 1), (partner, 1), (succeed, 1...      gas
# 490  [(gas, 2), (say, 2), (islamist, 1), (rebel, 1)...      gas
# 511  [(gas, 2), (China, 1), (eager, 1), (wean, 1), ...      gas
# 616  [(gas, 1), (oil, 1), (price, 1), (fall, 1), (r...      gas
# 668  [(gas, 2), (agency, 1), (say, 1), (rule, 1), (...      gas
# 672  [(gas, 2), (oil, 1), (industry, 1), (banker, 1...      gas

# %%
combined_news_day.loc[combined_news_day['top_word'] == 'Energy']
# Out:
#                                       combined_absract        Date  \
# 1    PetroBakken Energy said that it had paid $262 ...  2010-01-05
# 190  Energy Secretary Chu names a panel to study th...  2011-05-06
# 260  The French oil giant Total is acquiring a big ...  2012-01-03
#
#                                        abstract_tokens  \
# 1    [PetroBakken, Energy, said, that, it, had, pai...
# 190  [Energy, Secretary, Chu, names, a, panel, to, ...
# 260  [The, French, oil, giant, Total, is, acquiring...
#
#                                         abstract_lemma  \
# 1    [PetroBakken, Energy, say, pay, $, 262, millio...
# 190  [Energy, Secretary, Chu, name, panel, study, c...
# 260  [french, oil, giant, Total, acquire, big, piec...
#
#                                                 counts top_word
# 1    [(Energy, 2), (PetroBakken, 1), (say, 1), (pay...   Energy
# 190  [(Energy, 1), (Secretary, 1), (Chu, 1), (name,...   Energy
# 260  [(Energy, 2), (shale, 2), (operation, 2), ($, ...   Energy

# %%
combined_news_day.loc[combined_news_day['top_word'] == 'oil']
# Out:
#                                       combined_absract        Date  \
# 11   Hoping to increase Venezuela’s flagging oil pr...  2010-02-11
# 14   The oil and gas driller is looking to dispose ...  2010-02-17
# 15   Exxon Mobil replaced 100 percent of 2009 oil p...  2010-02-18
# 34   The Norwegian energy company says it is workin...  2010-04-20
# 38   As nerve-racking as the recent oil spill in th...  2010-04-29
# ..                                                 ...         ...
# 904  For decades, opposition to drilling has left t...  2018-12-03
# 907  The Trump administration has touted increased ...  2018-12-07
# 916  Innovation, investment and inviting geology ha...  2019-02-03
# 942  The skinny waterway, the gateway for a third o...  2019-06-13
# 966  The oil giant’s shares reached prices on the R...  2019-12-11
#
#                                        abstract_tokens  \
# 11   [Hoping, to, increase, Venezuela, ’s, flagging...
# 14   [The, oil, and, gas, driller, is, looking, to,...
# 15   [Exxon, Mobil, replaced, 100, percent, of, 200...
# 34   [The, Norwegian, energy, company, says, it, is...
# 38   [As, nerve, -, racking, as, the, recent, oil, ...
# ..                                                 ...
# 904  [For, decades, ,, opposition, to, drilling, ha...
# 907  [The, Trump, administration, has, touted, incr...
# 916  [Innovation, ,, investment, and, inviting, geo...
# 942  [The, skinny, waterway, ,, the, gateway, for, ...
# 966  [The, oil, giant, ’s, shares, reached, prices,...
#
#                                         abstract_lemma  \
# 11   [hope, increase, Venezuela, flag, oil, product...
# 14   [oil, gas, driller, look, dispose, $, 2, billi...
# 15   [Exxon, Mobil, replace, 100, percent, 2009, oi...
# 34   [norwegian, energy, company, say, work, new, t...
# 38   [nerve, rack, recent, oil, spill, gulf, reason...
# ..                                                 ...
# 904  [decade, opposition, drilling, leave, Arctic, ...
# 907  [Trump, administration, tout, increase, energy...
# 916  [Innovation, investment, invite, geology, give...
# 942  [skinny, waterway, gateway, crude, oil, tanker...
# 966  [oil, giant, share, reach, price, Riyadh, exch...
#
#                                                 counts top_word
# 11   [(oil, 2), (hope, 1), (increase, 1), (Venezuel...      oil
# 14   [(oil, 1), (gas, 1), (driller, 1), (look, 1), ...      oil
# 15   [(oil, 2), (Exxon, 1), (Mobil, 1), (replace, 1...      oil
# 34   [(oil, 2), (norwegian, 1), (energy, 1), (compa...      oil
# 38   [(oil, 2), (nerve, 1), (rack, 1), (recent, 1),...      oil
# ..                                                 ...      ...
# 904  [(oil, 2), (decade, 1), (opposition, 1), (dril...      oil
# 907  [(oil, 2), (Trump, 1), (administration, 1), (t...      oil
# 916  [(oil, 2), (Innovation, 1), (investment, 1), (...      oil
# 942  [(oil, 2), (skinny, 1), (waterway, 1), (gatewa...      oil
# 966  [(oil, 1), (giant, 1), (share, 1), (reach, 1),...      oil
#
# [84 rows x 6 columns]

# %%
combined_news_day.loc[combined_news_day['top_word'] == 'Trump']
# Out:
#                                       combined_absract        Date  \
# 902  The Trump administration’s policy of encouragi...  2018-11-27
#
#                                        abstract_tokens  \
# 902  [The, Trump, administration, ’s, policy, of, e...
#
#                                         abstract_lemma  \
# 902  [Trump, administration, policy, encourage, oil...
#
#                                                 counts top_word
# 902  [(Trump, 1), (administration, 1), (policy, 1),...    Trump

# %%
combined_news_day.loc[combined_news_day['top_word'] == 'Shell']
# Out:
#                                       combined_absract        Date  \
# 214  Shell was under pressure after it emerged that...  2011-08-16
# 215  Shell’s plan to drill four exploratory oil wel...  2011-08-18
# 313  The oil and natural gas exploration company Co...  2012-05-23
# 619  Shell is dismantling its North Sea project, a ...  2015-02-18
#
#                                        abstract_tokens  \
# 214  [Shell, was, under, pressure, after, it, emerg...
# 215  [Shell, ’s, plan, to, drill, four, exploratory...
# 313  [The, oil, and, natural, gas, exploration, com...
# 619  [Shell, is, dismantling, its, North, Sea, proj...
#
#                                         abstract_lemma  \
# 214  [Shell, pressure, emerge, company, wait, day, ...
# 215  [Shell, plan, drill, exploratory, oil, well, A...
# 313  [oil, natural, gas, exploration, company, Cove...
# 619  [Shell, dismantle, North, Sea, project, step, ...
#
#                                                 counts top_word
# 214  [(Shell, 1), (pressure, 1), (emerge, 1), (comp...    Shell
# 215  [(Shell, 1), (plan, 1), (drill, 1), (explorato...    Shell
# 313  [(Shell, 2), (oil, 1), (natural, 1), (gas, 1),...    Shell
# 619  [(Shell, 1), (dismantle, 1), (North, 1), (Sea,...    Shell

# %%
combined_news_day.loc[combined_news_day['top_word'] == 'Saudi']
# Out:
#                                       combined_absract        Date  \
# 716  Saudi Arabia, Russia, Venezuela and Qatar agre...  2016-02-16
# 866  Saudi Arabia’s national oil company has served...  2018-05-08
#
#                                        abstract_tokens  \
# 716  [Saudi, Arabia, ,, Russia, ,, Venezuela, and, ...
# 866  [Saudi, Arabia, ’s, national, oil, company, ha...
#
#                                         abstract_lemma  \
# 716  [Saudi, Arabia, Russia, Venezuela, Qatar, agre...
# 866  [Saudi, Arabia, national, oil, company, serve,...
#
#                                                 counts top_word
# 716  [(Saudi, 1), (Arabia, 1), (Russia, 1), (Venezu...    Saudi
# 866  [(Saudi, 1), (Arabia, 1), (national, 1), (oil,...    Saudi
