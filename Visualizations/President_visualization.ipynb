# %% [markdown]
# # President Visualization

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import plotly.express as pximport 
import hvplot.pandas
import holoviews as hv
from holoviews import opts
import matplotlib.pyplot as plt
import datetime as dt

# %%
df_visualization = pd.read_pickle("../prediction_prices.pkl")

# %%
president_df = df_visualization.reset_index()

# %%
president_df.dtypes
# Out:
# date      datetime64[ns]
# Prices           float64
# dtype: object

# %%
list(president_df.columns.values)
# Out:
# ['date', 'Prices']

# %%
president_curve_plot = president_df.plot(x='date', y='Prices', figsize=(20,10), legend=True)

# %%
president_curve_plot = president_df.plot(x='date', y='Prices',figsize=(20,10))
president_curve_plot.axvline(dt.datetime(2019, 9, 21), color='red', label= "Obama")
president_curve_plot.axvline(dt.datetime(2018, 12, 17), color='green', label= "Trump")
plt.show()
