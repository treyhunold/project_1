# %% [markdown]
# # Sector Visualizations

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import plotly.express as pximport 
import hvplot.pandas
import holoviews as hv
from holoviews import opts
import matplotlib.pyplot as plt
import datetime as dt

# %%
df_visualization = pd.read_pickle("../prediction_prices.pkl")

# %% [markdown]
# ## Gas Visualization

# %%
gas_df = gas_visualization.reset_index()

# %%
gas_df.dtypes
# Out:
# date      datetime64[ns]
# Prices           float64
# dtype: object

# %%
list(gas_df.columns.values)
# Out:
# ['date', 'Prices']

# %%
gas_curve_plot = gas_df.plot(x='date', y='Prices',figsize=(20,10))

# %%
gas_curve_plot = gas_df.plot(x='date', y='Prices',figsize=(20,10))
#Dates where Gas was the most frequent word
gas_curve_plot.axvline(dt.datetime(2019, 9, 21), color='red')
gas_curve_plot.axvline(dt.datetime(2018, 12, 17), color='red')
# #Dates where Energy was the most frequent word
# gas_curve_plot.axvline(dt.datetime(2019, 7, 21), color='green')
# gas_curve_plot.axvline(dt.datetime(2018, 10, 17), color='green')
plt.show()

# %% [markdown]
# ## Energy Visualization

# %%
energy_df = df_visualization.reset_index()

# %%
energy_df.dtypes
# Out:
# date      datetime64[ns]
# Prices           float64
# dtype: object

# %%
list(energy_df.columns.values)
# Out:
# ['date', 'Prices']

# %%
energy_curve_plot = energy_df.plot(x='date', y='Prices',figsize=(20,10))

# %%
energy_curve_plot.axvline(dt.datetime(2012, 9, 21))
energy_curve_plot

# %%
energy_curve_plot = energy_df.plot(x='date', y='Prices',figsize=(20,10))
energy_curve_plot.axvline(dt.datetime(2019, 9, 21), color='green')
energy_curve_plot.axvline(dt.datetime(2018, 12, 17), color='green')
plt.show()
