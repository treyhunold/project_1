# %%
import pandas as pd
import numpy as np
from pathlib import Path
import plotly.express as pximport 
import hvplot.pandas
import holoviews as hv
from holoviews import opts
import matplotlib.pyplot as plt
import datetime as dt

# %%
word2_visualization = pd.read_pickle("../prediction_prices.pkl")

# %%
df = word2_visualization.reset_index()

# %%
df
# Out:
#           date      value
# 0   2010-02-09  77.130289
# 1   2010-02-10  68.628883
# 2   2010-02-11  85.585538
# 3   2010-02-16  66.822547
# 4   2010-02-17  68.629125
# ..         ...        ...
# 898 2019-12-12  51.977709
# 899 2019-12-13  77.130289
# 900 2019-12-16  77.130289
# 901 2019-12-17  67.679971
# 902 2019-12-24  70.586600
#
# [903 rows x 2 columns]

# %%
df.dtypes
# Out:
# date      datetime64[ns]
#  value           float64
# dtype: object

# %%
list(df.columns.values)
# Out:
# ['date', ' value']

# %%
curve_plot = df.plot(x='date', y=' value',figsize=(20,10))

# %%
curve_plot.axvline(dt.datetime(2012, 9, 21))
curve_plot

# %%
word2_vis_plot = hv.Curve(df).opts(
    opts.Curve(height=500, width=1000, title= "Word2 Visualization"))
word2_vis_plot
# Out:
# :Curve   [date]   ( value)

# %%
curve_plot = df.plot(x='date', y=' value',figsize=(20,10))
curve_plot.axvline(dt.datetime(2012, 9, 21), color='red')
curve_plot.axvline(dt.datetime(2017, 12, 17), color='red')
plt.show()

# %%
word2_vis_plot * vline2_plot
