# %%
import pandas as pd
import numpy as np
from pathlib import Path
import plotly.express as pximport 
import hvplot.pandas
import holoviews as hv
from holoviews import opts

# %%
word1_visualization = pd.read_pickle("../prediction_prices.pkl")

# %%
word1_visualization.reset_index()
# Out:
#           date      value
# 0   2010-02-09  77.130289
# 1   2010-02-10  68.628883
# 2   2010-02-11  85.585538
# 3   2010-02-16  66.822547
# 4   2010-02-17  68.629125
# ..         ...        ...
# 898 2019-12-12  51.977709
# 899 2019-12-13  77.130289
# 900 2019-12-16  77.130289
# 901 2019-12-17  67.679971
# 902 2019-12-24  70.586600
#
# [903 rows x 2 columns]

# %%
word1_vis_plot = hv.Curve(word1_visualization).opts(
    opts.Curve(height=500, width=1000, title= "Word1 Visualization"))
word1_vis_plot
# Out:
# :Curve   [date]   ( value)

# %%
vline1_dates = pd.DataFrame({'dates': [2019-12-17, 2019-12-12, 2019-12-13]})
vline1_plot = hv.VLine(vline1_dates)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-123-66faa1b6b7f0> in <module>
#       1 vline_dates = pd.DataFrame({'dates': [2019-12-17, 2019-12-12, 2019-12-13]})
# ----> 2 vline_plot = hv.VLine(vline_dates)
#
# ~/opt/anaconda3/envs/vizenv/lib/python3.7/site-packages/holoviews/element/annotation.py in __init__(self, x, **params)
#      96
#      97     def __init__(self, x, **params):
# ---> 98         super(VLine, self).__init__(x, x=x, **params)
#      99
#     100     def dimension_values(self, dimension, expanded=True, flat=True):
#
# ~/opt/anaconda3/envs/vizenv/lib/python3.7/site-packages/holoviews/element/annotation.py in __init__(self, data, **params)
#      31
#      32     def __init__(self, data, **params):
# ---> 33         super(Annotation, self).__init__(data, **params)
#      34
#      35     def __len__(self):
#
# ...

# %%
word1_vis_plot * vline1_plot
# Out:
# :Overlay
#    .Curve.I :Curve   [date]   ( value)
#    .VLine.I :VLine   [x,y]
