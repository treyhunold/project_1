# %% [markdown]
# # Sector Visualizations

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import plotly.express as pximport 
import hvplot.pandas
import holoviews as hv
from holoviews import opts
import matplotlib.pyplot as plt
import datetime as dt

# %%
#read in the pickle file as a dataframe
df_visualization = pd.read_pickle("../prediction_oil_prices.pkl")

# %% [markdown]
# ## Gas Visualization

# %%
#reset index so there are two columns for date and prices
gas_df = df_visualization.reset_index()

# %%
#read the column types
gas_df.dtypes
# Out:
# date      datetime64[ns]
# Prices           float64
# dtype: object

# %%
#list the column values
list(gas_df.columns.values)
# Out:
# ['date', 'Prices']

# %%
#Create plot with vlines for the dates in which the word was most frequently used
gas_curve_plot = gas_df.plot(x='date', y='Prices', figsize=(20,10), legend=True)
gas_curve_plot.set_xlabel("Article Date")
gas_curve_plot.set_ylabel("Oil Prices")
gas_curve_plot.set_title("Article's with Gas as the most frequest word")
gas_curve_plot.axvline(dt.datetime(2010, 10, 13), color='green')
gas_curve_plot.axvline(dt.datetime(2010, 8, 5), color='green')
gas_curve_plot.axvline(dt.datetime(2011, 12, 10), color='green')
gas_curve_plot.axvline(dt.datetime(2011, 12, 2), color='green')
gas_curve_plot.axvline(dt.datetime(2012, 9, 5), color='green')
gas_curve_plot.axvline(dt.datetime(2012, 8, 16), color='green')
gas_curve_plot.axvline(dt.datetime(2012, 3, 30), color='green')
gas_curve_plot.axvline(dt.datetime(2013, 10, 3), color='green')
gas_curve_plot.axvline(dt.datetime(2013, 3, 12), color='green')
gas_curve_plot.axvline(dt.datetime(2014, 4, 12), color='green')
gas_curve_plot.axvline(dt.datetime(2015, 9, 14), color='green')
gas_curve_plot.axvline(dt.datetime(2015, 8, 18), color='green')
gas_curve_plot.axvline(dt.datetime(2015, 2, 11), color='green')
plt.show()

# %% [markdown]
# ## Energy Visualization

# %%
#reset index so there are two columns for date and prices
energy_df = df_visualization.reset_index()

# %%
#read the column types
energy_df.dtypes
# Out:
# date      datetime64[ns]
# Prices           float64
# dtype: object

# %%
#list the column values
list(energy_df.columns.values)
# Out:
# ['date', 'Prices']

# %%
#Create plot with vlines for the dates in which the word was most frequently used
energy_curve_plot = energy_df.plot(x='date', y='Prices', figsize=(20,10), legend=True)
energy_curve_plot.set_xlabel("Article Date")
energy_curve_plot.set_ylabel("Oil Prices")
energy_curve_plot.set_title("Article's with Energy as the most frequest word")
energy_curve_plot.axvline(dt.datetime(2010, 12, 16), color='red')
energy_curve_plot.axvline(dt.datetime(2011, 5, 6), color='red')
energy_curve_plot.axvline(dt.datetime(2011, 2, 3), color='red')
energy_curve_plot.axvline(dt.datetime(2012, 1, 3), color='red')
energy_curve_plot.axvline(dt.datetime(2014, 3, 12), color='red')
plt.show()
