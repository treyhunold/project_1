# %%
import pandas as pd
import numpy as np
from pathlib import Path
import plotly.express as pximport 
import hvplot.pandas
import holoviews as hv
from holoviews import opts
import matplotlib.pyplot as plt
import datetime as dt

# %%
geo_visualization = pd.read_pickle("../prediction_oil_prices.pkl")

# %%
df = geo_visualization.reset_index()

# %%
df
# Out:
#           date     Prices
# 0   2010-02-09  78.815001
# 1   2010-02-10  68.484893
# 2   2010-02-11  85.844077
# 3   2010-02-16  69.349223
# 4   2010-02-17  68.772696
# ..         ...        ...
# 898 2019-12-12  50.782907
# 899 2019-12-13  78.815001
# 900 2019-12-16  78.815001
# 901 2019-12-17  67.464596
# 902 2019-12-24  97.542400
#
# [903 rows x 2 columns]

# %%
df.dtypes
# Out:
# date      datetime64[ns]
# Prices           float64
# dtype: object

# %%
list(df.columns.values)
# Out:
# ['date', 'Prices']

# %%
curve_plot = df.plot(x='date', y='Prices',figsize=(20,10))

# %%
# Adding Vlines (USA) to the plot 
curve_plot = df.plot(x='date', y='Prices',figsize=(20,10),)
curve_plot.axvline(dt.datetime(2012, 6, 9), color='red')
curve_plot.axvline(dt.datetime(2012, 11, 12), color='red')
curve_plot.axvline(dt.datetime(2012, 12, 13), color='red')
curve_plot.axvline(dt.datetime(2014, 3, 7), color='red')
curve_plot.axvline(dt.datetime(2014, 4, 21), color='red')
curve_plot.axvline(dt.datetime(2014, 9, 13), color='red')
curve_plot.axvline(dt.datetime(2015, 4, 21), color='red')
curve_plot.axvline(dt.datetime(2017, 10, 16), color='red')
curve_plot.axvline(dt.datetime(2018, 6, 6), color='red')
curve_plot.axvline(dt.datetime(2018, 6, 13), color='red')
curve_plot.axvline(dt.datetime(2019, 1, 25), color='red')
plt.show()
title('Articles that mention the top word USA')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-2d103d165a59> in <module>
#      13 curve_plot.axvline(dt.datetime(2019, 1, 25), color='red')
#      14 plt.show()
# ---> 15 title('Articles that mention the top word USA')
#
# NameError: name 'title' is not defined

# %%
# Adding Vlines (China) to the plot 
curve_plot = df.plot(x='date', y='Prices',figsize=(20,10),)
curve_plot.axvline(dt.datetime(2014, 5, 22), color='y')
curve_plot.axvline(dt.datetime(2014, 9, 25), color='y')
curve_plot.axvline(dt.datetime(2014, 12, 20), color='y')
curve_plot.axvline(dt.datetime(2015, 10, 23), color='y')
curve_plot.axvline(dt.datetime(2016, 1, 9), color='y')
curve_plot.axvline(dt.datetime(2017, 11, 3), color='y')
plt.show()
